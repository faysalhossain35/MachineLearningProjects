# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset1=randn(100)

# %% [markdown]
# ## Histogram

# %%
plt.hist(dataset1)
# Out:
# (array([ 6., 10., 15., 25., 11., 19.,  3.,  8.,  2.,  1.]),
#  array([-1.52861197, -1.11425435, -0.69989672, -0.2855391 ,  0.12881853,
#          0.54317616,  0.95753378,  1.37189141,  1.78624903,  2.20060666,
#          2.61496428]),
#  <a list of 10 Patch objects>)

# %%
dataset2=randn(80)
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 3.,  2.,  3., 12., 16., 13., 18.,  7.,  1.,  5.]),
#  array([-3.05017657, -2.49946402, -1.94875147, -1.39803892, -0.84732637,
#         -0.29661382,  0.25409874,  0.80481129,  1.35552384,  1.90623639,
#          2.45694894]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.1361872 , 0.        , 0.        , 0.09079147, 0.04539573,
#         0.09079147, 0.36316586, 0.18158293, 0.36316586, 0.36316586,
#         0.09079147, 0.49935306, 0.2723744 , 0.5447488 , 0.18158293,
#         0.1361872 , 0.04539573, 0.        , 0.04539573, 0.18158293]),
#  array([-3.05017657, -2.7748203 , -2.49946402, -2.22410775, -1.94875147,
#         -1.67339519, -1.39803892, -1.12268264, -0.84732637, -0.57197009,
#         -0.29661382, -0.02125754,  0.25409874,  0.52945501,  0.80481129,
#          1.08016756,  1.35552384,  1.63088011,  1.90623639,  2.18159267,
#          2.45694894]),
#  <a list of 20 Patch objects>)

# %%
data1=randn(1000)
data2=randn(1000)

# %%
sns.jointplot(data1,data2)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(data1,data2,kind='hex')
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
dataset=randn(25)

# %%
sns.rugplot(dataset)

# %%
plt.hist(dataset,alpha=0.3)
sns.rugplot(dataset)

# %% [markdown]
# # Kernel Density Estimation plot

# %%
sns.kdeplot(dataset)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.rugplot(dataset,color='black')
for bw in np.arange(0.5,2,0.25):
    sns.kdeplot(dataset,bw=bw,lw=1.8,label=bw)

# %%
kernel_option=['biw','cos','epa','gau','tri','triw']
for kern in kernel_option:
    sns.kdeplot(dataset,kernel=kern,label=kern,shade=True)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(dataset,vertical=True)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
mean=[0,0]
cov=[[1,0],[0,100]]
dataset2=np.random.multivariate_normal(mean,cov,1000)
dframe=pd.DataFrame(dataset2,columns=['X','Y'])
sns.kdeplot(dframe)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:645: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(dframe.X,dframe.Y,shade=True)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(dframe,bw=1)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:645: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.jointplot('X','Y',dframe,kind='kde')
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
dataset = randn(100)

# %%
sns.distplot(dataset,bins=25)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(dataset,bins=25,rug=True,hist=False)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(dataset,bins=25,
            kde_kws={'color':'indianred','label':'KDE PLOT'},
            hist_kws={'color':'blue','label':'HIST PLOT'})
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from pandas import Series
ser1=Series(dataset,name='My_data')
ser1
# Out:
# 0     0.711043
# 1     0.334343
# 2    -0.863576
# 3     0.468185
# 4     1.145632
# 5    -0.237728
# 6     1.207497
# 7    -0.642214
# 8    -0.137961
# 9    -2.046269
# 10    0.030184
# 11   -0.071201
# 12   -0.243139
# 13   -1.579273
# 14    0.906676
# 15    0.882008
# 16   -0.509112
# 17   -0.953139
# 18    0.295872
# 19    0.462916
# 20   -0.294201
# 21   -0.249712
# 22   -0.516554
# 23    0.795587
# 24    0.075663
# 25    1.473214
# 26   -0.720485
# 27   -0.257867
# 28   -0.599783
# 29    0.158644
#         ...
# 70    0.457057
# 71    0.048261
# 72   -0.978027
# 73    0.751451
# 74    0.449675
# 75   -0.948104
# 76    0.271691
# 77   -1.076853
# 78    1.647944
# 79   -0.147025
# 80   -2.850381
# 81   -0.298996
# 82    0.089974
# 83   -0.236128
# 84   -0.658789
# 85   -0.659837
# 86   -0.398251
# 87   -0.566107
# 88    0.994675
# 89    0.584950
# 90    0.240158
# 91   -0.031725
# 92   -0.826789
# 93   -1.462577
# 94   -1.160612
# 95    0.151547
# 96    0.454560
# 97    0.723911
# 98   -0.733719
# 99   -0.593836
# Name: My_data, Length: 100, dtype: float64

# %%
sns.distplot(ser1,bins=25)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data1=randn(100)
data2=randn(100)
data=[data1,data2]
data
# Out:
# [array([-0.9336948 , -0.77380362, -1.71691204, -1.12827786,  0.39301254,
#          0.37722983,  0.75127188,  1.45760086,  1.23309192,  0.10485148,
#         -0.16747689, -1.18164555,  1.0121164 ,  0.33300648,  0.68607533,
#          0.39656298, -0.26142009,  1.05433136, -1.96047185,  0.27517555,
#          0.32528496, -1.18938891, -2.35729356, -0.65594732,  1.08497999,
#         -0.53652588,  0.89312186,  0.73708289,  0.38317994,  0.9001098 ,
#          1.99513151,  0.95525177,  0.53052871,  1.4846113 , -0.37274762,
#         -1.81931628, -0.02153147,  1.16594756,  1.46138035, -0.75685161,
#          0.90441504,  0.42352632,  0.48438717,  0.92004076, -0.40273741,
#         -0.20805756,  0.68718795,  0.03546985, -0.70469007, -0.64088502,
#         -0.82684588,  1.12931692,  0.81837118,  0.18735498, -0.59935941,
#         -0.26701723, -0.4230904 ,  0.07072865,  1.97048643, -0.52688688,
#          0.7410227 , -0.03216567,  2.15899936, -0.56802021, -0.87687748,
#         -1.46797699,  2.14978328, -0.14092705, -2.24953897, -0.45781988,
#         -0.55432357, -0.89807041, -1.24504471,  0.61069392, -0.13967211,
#         -1.13832432, -0.87036031, -0.92574425, -1.58330249,  0.16399244,
#         -0.12014634, -1.02886793,  0.88850232, -1.1126693 , -0.30268411,
#         -0.05495714,  0.31810599,  0.20540193, -0.08252585, -1.14910049,
#          1.70938642,  1.86872935,  1.82102854,  0.23699422,  1.50818031,
#         -1.90791447,  0.1425016 ,  0.32180483, -0.8087882 , -1.32520945]),
#  array([-0.28665934, -1.15916335,  2.26429959,  1.36625162,  0.0230197 ,
#         -0.01442611,  1.41222017, -1.09623582, -0.20612848, -1.32780534,
#          1.98834307,  0.50402853,  1.42497316, -0.99927806, -0.60994114,
#          3.30600777,  0.89418886,  2.11078802, -0.69627983,  0.55329698,
#         -1.18994412,  0.4954546 , -2.14878694, -1.9178814 ,  0.53615626,
#         -0.08330955, -0.36731714,  0.4072251 , -0.54811053,  0.64946039,
#         -0.08760168, -2.67214944,  1.01220038, -0.42073868, -0.45442222,
#         -0.62812254,  0.04999158, -1.37340676, -0.28046108, -0.59083782,
#         -0.08177   , -2.47925812, -1.88322773,  0.11611504,  0.08674915,
#          0.07412136,  0.86813435, -1.41055111, -1.46228677,  0.44031927,
#         -0.22441995, -0.26036435, -0.28657961,  0.57031858, -0.41609624,
#         -0.80986377, -1.49541753, -1.77699857,  1.0070769 , -0.72665213,
#          0.34631713,  0.43785426, -0.88046585,  0.24362279,  0.85421255,
#          0.32651133,  0.04509531, -1.54500578, -1.53734951, -1.19280844,
#         -0.77710654, -0.08997362, -0.37004183,  0.29100969,  3.15266854,
#          0.62318795, -0.27017055, -1.07316322, -0.09202656,  0.9899702 ,
#         -0.40134415, -0.64350892, -0.81680749, -0.37549967, -1.22355408,
#         -0.3900537 ,  0.66822223, -0.0372656 , -0.35566809, -0.84855335,
#         -0.33629877,  1.1473498 , -0.62792804,  0.02201715,  1.09123373,
#         -0.3567052 ,  1.10113038,  1.2634771 ,  1.31466079,  2.37429729])]

# %%
sns.boxplot(data,orient='v')

# %%
sns.boxplot([data1,data2],whis=np.inf)

# %%
sns.violinplot([data1,data2],bw=0.01)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(data1,inner='stick')

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot('total_bill','tip',tips)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot('total_bill','tip',tips,order=4,
          scatter_kws={'marker':'o','color':'indianred'},
          line_kws={'linewidth':1,'color':'blue'})
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pect']=100*(tips['tip']/tips['total_bill'])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
sns.lmplot('size','tip_pect',tips)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot('size','tip_pect',tips,x_jitter=0.1)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot('size','tip_pect',tips,x_estimator=np.mean)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot('total_bill','tip_pect',tips,hue='sex',markers=['x','o'])
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot('total_bill','tip_pect',tips,hue='day')
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot('total_bill','tip_pect',tips)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig,(axis1,axis2)= plt.subplots(1,2,sharey=True)
sns.regplot('total_bill','tip_pect',tips,ax=axis1)
sns.violinplot(x="tip_pect", y="size", data=tips,ax=axis2)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x="tip_pect", y="size", data=tips)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
# Out:
# C:\Users\Faysal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
dflight=sns.load_dataset('flights')

# %%
dflight.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
dflight=dflight.pivot('month','year','passengers')
dflight
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# December    118   140   166   194   201   229   278   306   336   337   405
#
# year       1960
# month
# January     417
# February    391
# March       419
# April       461
# May         472
# June        535
# July        622
# August      606
# September   508
# October     461
# November    390
# December    432

# %%
sns.heatmap(dflight)

# %%
sns.heatmap(dflight,annot=True,fmt='d')
